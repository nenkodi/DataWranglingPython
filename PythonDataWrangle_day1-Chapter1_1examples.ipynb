# %% [markdown]
# # Examples from chapter 1.1
# Below you can find the examples which were given during the first part of Chapter 1. this is maly for type of variables.

# %%
coffee = 3.50

# %%
c = 3.5

# %%
VAT = 0.2

# %%
coffee + 1
# Out:
# 4.5

# %%
coffee
# Out:
# 3.5

# %%
coffee = coffee +1

# %%
coffee
# Out:
# 4.5

# %%
x=5

# %%
x=x*2

# %%
print (x)
# Out:
# 10

# %%
x=x-9

# %%
x
# Out:
# 1

# %%
y=10/2

# %%
y
# Out:
# 5.0

# %%
#Division with remainder:
y=11%2

# %%
y
# Out:
# 1

# %%
#Powers
a=10**2

# %%
a
# Out:
# 100

# %%
#shift+Enter = play - shortcut

# %%
b=5**2

# %%
b
# Out:
# 25

# %%
#// returns the floor of the result of the division, so 13 // 4=3
x=4//3

# %%
x
# Out:
# 1

# %%
x=10//3

# %%
x
# Out:
# 3

# %%
x='transformers'

# %%
x
# Out:
# 'transformers'

# %%
x='transformers in terms of electrical equipment'

# %%
#how to get variable type:
type(x)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
type(coffee)
# Out:
# float

# %%
result = True

# %%
type(result)
# Out:
# bool

# %%
#changing variable (casting):
mynumber = '15'
int(mynumber)
# Out:
# 15

# %%
type (mynumber)
# Out:
# str

# %%
int(mynumber)
# Out:
# 15

# %%
type(mynumber)
# Out:
# str

# %%
mynumber = '15'

# %%
mynumber
# Out:
# '15'

# %%
mynumber=int(mynumber)

# %%
type(mynumber)
# Out:
# int

# %%
coffee
# Out:
# 4.5

# %%
coffee>3
# Out:
# True

# %%
tea=4

# %%
coffee>tea
# Out:
# True

# %%
coffee>3 and tea>3
# Out:
# True

# %%
coffee==3.5
# Out:
# False

# %%
coffee!=0
# Out:
# True

# %%
#coffee=coffee + 1 -> coffee + = 1
