# %% [markdown]
# # From Raw Data to DataFrames

# %% [markdown]
# From the course presentation page 283

# %% [markdown]
# ![image.png](attachment:fcd1f9f6-e0ad-4a2b-b904-1e39a72d128f.png)

# %% [markdown]
# We can create our own finctions:
#
# ![image.png](attachment:e9ade999-138b-4248-b988-e1ef2ddb56ac.png)

# %% [markdown]
# Messy data vs tidy data means that we need to have one measurement per record.

# %% [markdown]
# Here the issue is that we have totals
#
# ![image.png](attachment:a974c024-f435-46f0-a793-00c3650b5672.png)

# %% [markdown]
# You can find the resolutions of the problems in the slides

# %% [markdown]
# **melt()** Function is unpivoting the tables.
